# %% [markdown]
# # Plot of clustering for w = 0, 0.01, 0.1
# Data extracted from file
#
# To change to simulation change all '.npy to '_k_2.npy and replicates/Replicates to simulations in paths.

# %%
import sys
sys.path.insert(1, '/home/elinfi/MasterCode/notebooks/plotting')

# %%
import os

import numpy as np

import plot_clusters as plotc

# %%
PATH_CLUSTER = '/home/elinfi/MasterCode/data/simulations/clusters'
PATH_IMG = '/home/elinfi/MasterCode/img/simulations/clusters'
PATH_DIFF = '/home/elinfi/MasterCode/data/simulations'
REGION = 'chr10:6351511-10351511'
wdiag = 0.001

# %% [markdown]
# ## Subtraction

# %%
# load dataset
wdiags = [0, 0.01, 0.1]
sub = np.load(os.path.join(PATH_DIFF, REGION + '_sub' + '_k_2.npy'))
cluster_sub_1 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                     + f'_sub_cluster_wdiag_{wdiags[0]}_medoids_5.npy'))
cluster_sub_2 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                      + f'_sub_cluster_wdiag_{wdiags[1]}_medoids_5.npy'))
cluster_sub_3 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                       + f'_sub_cluster_wdiag_{wdiags[2]}_medoids_5.npy'))

plotc.sub_cluster(sub, cluster_sub_1, cluster_sub_2, cluster_sub_3, 5, 
                  REGION, wdiags, figsize=(18, 15), path=PATH_IMG, save=True)

# %% [markdown]
# # Relative difference

# %%
# load dataset
wdiags = [0, 0.01, 0.1]
rel = np.load(os.path.join(PATH_DIFF, REGION + '_reldiff' + '_k_2.npy'))
cluster_rel_1 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                     + f'_reldiff_cluster_wdiag_{wdiags[0]}_medoids_5.npy'))
cluster_rel_2 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                      + f'_reldiff_cluster_wdiag_{wdiags[1]}_medoids_5.npy'))
cluster_rel_3 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                       + f'_reldiff_cluster_wdiag_{wdiags[2]}_medoids_5.npy'))

plotc.rel_cluster(rel, cluster_rel_1, cluster_rel_2, cluster_rel_3, 5, 
                  REGION, wdiags, figsize=(18, 15), path=PATH_IMG, save=True)

# %% [markdown]
# # Poisson

# %%
# load dataset
wdiags = [0, 0.01, 0.1]
poisson = np.load(os.path.join(PATH_DIFF, REGION + '_poisson' + '_k_2.npy'))
cluster_poisson_1 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                     + f'_poisson_cluster_wdiag_{wdiags[0]}_medoids_5.npy'))
cluster_poisson_2 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                      + f'_poisson_cluster_wdiag_{wdiags[1]}_medoids_5.npy'))
cluster_poisson_3 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                       + f'_poisson_cluster_wdiag_{wdiags[2]}_medoids_5.npy'))

plotc.poisson_cluster(poisson, cluster_poisson_1, cluster_poisson_2, cluster_poisson_3, 5, 
                  REGION, wdiags, figsize=(18, 15), path=PATH_IMG, save=True)

# %% [markdown]
# # Fold change

# %%
# load dataset
wdiags = [0, 0.01, 0.1]
ratio = np.load(os.path.join(PATH_DIFF, REGION + '_ratio' + '_k_2.npy'))
cluster_ratio_1 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                     + f'_ratio_log_cluster_wdiag_{wdiags[0]}_medoids_5.npy'))
cluster_ratio_2 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                      + f'_ratio_log_cluster_wdiag_{wdiags[1]}_medoids_5.npy'))
cluster_ratio_3 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                       + f'_ratio_log_cluster_wdiag_{wdiags[2]}_medoids_5.npy'))
plotc.ratio_cluster(ratio, cluster_ratio_1, cluster_ratio_2, cluster_ratio_3, 5, 
                  REGION, wdiags, figsize=(18, 15), path=PATH_IMG, save=True)
# Out:
# /home/elinfi/MasterCode/src/class/mid_point_log_norm.py:15: RuntimeWarning: invalid value encountered in log2
#   return np.ma.array(np.interp(np.log2(result), x, y), mask=result.mask, copy=False)

# %% [markdown]
# # Fold change HiGlass

# %%
# load dataset
wdiags = [0, 0.01, 0.1]
ratio_higlass = np.load(os.path.join(PATH_DIFF, REGION + '_ratio' + '_k_2.npy'))
cluster_ratio_higlass_1 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                     + f'_ratio_higlass_cluster_wdiag_{wdiags[0]}_medoids_5.npy'))
cluster_ratio_higlass_2 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                      + f'_ratio_higlass_cluster_wdiag_{wdiags[1]}_medoids_5.npy'))
cluster_ratio_higlass_3 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                       + f'_ratio_higlass_cluster_wdiag_{wdiags[2]}_medoids_5.npy'))

plotc.ratio_higlass_cluster(ratio_higlass, cluster_ratio_higlass_1, cluster_ratio_higlass_2, cluster_ratio_higlass_3, 5, 
                  REGION, wdiags, figsize=(18, 15), path=PATH_IMG, save=True)

# %% [markdown]
# # Pseudocount

# %%
# load dataset
wdiags = [0, 0.01, 0.1]
p1 = np.load(os.path.join(PATH_DIFF, REGION + '_p1' + '_k_2.npy'))
cluster_p1_1 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                     + f'_p1_cluster_wdiag_{wdiags[0]}_medoids_5.npy'))
cluster_p1_2 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                      + f'_p1_cluster_wdiag_{wdiags[1]}_medoids_5.npy'))
cluster_p1_3 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                       + f'_p1_cluster_wdiag_{wdiags[2]}_medoids_5.npy'))

plotc.pseudocount_cluster(p1, cluster_p1_1, cluster_p1_2, cluster_p1_3, 5, 
                  REGION, wdiags, pseudo=1, figsize=(18, 15), path=PATH_IMG, save=True)

# %%
# load dataset
wdiags = [0, 0.01, 0.1]
p01 = np.load(os.path.join(PATH_DIFF, REGION + '_p01' + '_k_2.npy'))
cluster_p01_1 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                     + f'_p01_cluster_wdiag_{wdiags[0]}_medoids_5.npy'))
cluster_p01_2 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                      + f'_p01_cluster_wdiag_{wdiags[1]}_medoids_5.npy'))
cluster_p01_3 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                       + f'_p01_cluster_wdiag_{wdiags[2]}_medoids_5.npy'))

plotc.pseudocount_cluster(p01, cluster_p01_1, cluster_p01_2, cluster_p01_3, 5, 
                  REGION, wdiags, pseudo=0.1, figsize=(18, 15), path=PATH_IMG, save=True)

# %%
# load dataset
wdiags = [0, 0.01, 0.1]
p001 = np.load(os.path.join(PATH_DIFF, REGION + '_p001' + '_k_2.npy'))
cluster_p001_1 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                     + f'_p001_cluster_wdiag_{wdiags[0]}_medoids_5.npy'))
cluster_p001_2 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                      + f'_p001_cluster_wdiag_{wdiags[1]}_medoids_5.npy'))
cluster_p001_3 = np.load(os.path.join(PATH_CLUSTER, REGION 
                                       + f'_p001_cluster_wdiag_{wdiags[2]}_medoids_5.npy'))

plotc.pseudocount_cluster(p001, cluster_p001_1, cluster_p001_2, cluster_p01_3, 5, 
                  REGION, wdiags, pseudo=0.01, figsize=(18, 15), path=PATH_IMG, save=True)
